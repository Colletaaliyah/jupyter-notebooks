# %% [markdown]
# ### 1.Importing modules that interact with the database.

# %%
import pandas as pd
import psycopg2

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
conn = psycopg2.connect("dbname=myduka user=postgres password=Candidcoco@20")

# %%
df = pd.read_sql_query("SELECT sales.id as sales_id, product_name, buying_price, selling_price, sales.quantity as sales_quantity, created_at as sales_created_at from products, sales WHERE products.id = sales.pid", conn)

# %% [markdown]
# ### 2. Setting Column index

# %%
df.set_index('sales_id',inplace=True,verify_integrity=False)

# %% [markdown]
# ### 3.Checking data types

# %%
df.dtypes
# Out:
# product_name                object
# buying_price                 int64
# selling_price                int64
# sales_quantity               int64
# sales_created_at    datetime64[ns]
# dtype: object

# %% [markdown]
# ### 4.Cleaning up columns to follow programming naming.

# %%
df.columns.to_list()
# Out:
# ['product_name',
#  'buying_price',
#  'selling_price',
#  'sales_quantity',
#  'sales_created_at']

# %% [markdown]
# ### 5. Removing duplicates.

# %%
df.shape
# Out:
# (50, 5)

# %%
new_df = df.append(df)
new_df.shape
# Out:
# (100, 5)

# %%
new_df = df.drop_duplicates()
new_df.shape
# Out:
# (50, 5)

# %% [markdown]
# ### 6.Dealing with null values.

# %% [markdown]
# ### 7. Summary Statistics.

# %%
profit = pd.read_sql_query("ALTER TABLE products ADD COLUMN profit int",conn)
df = df.assign(profit=profit)
# Out:
# ---------------------------------------------------------------------------
# DuplicateColumn                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2018, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2017 try:
# -> 2018     cur.execute(*args, **kwargs)
#    2019     return cur
#
# DuplicateColumn: column "profit" of relation "products" already exists
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 profit = pd.read_sql_query("ALTER TABLE products ADD COLUMN profit int",conn)
#       2 df = df.assign(profit=profit)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:397, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     339 """
#     340 Read SQL query into a DataFrame.
#     341
#    (...)
#     394 parameter will be converted to UTC.
#     395 """
#     396 pandas_sql = pandasSQL_builder(con)
# --> 397 return pandas_sql.read_query(
#     398     sql,
#     399     index_col=index_col,
#     400     params=params,
#     401     coerce_float=coerce_float,
#     402     parse_dates=parse_dates,
#     403     chunksize=chunksize,
#     404     dtype=dtype,
#     405 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2078, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2066 def read_query(
#    2067     self,
#    2068     sql,
#    (...)
#    2074     dtype: DtypeArg | None = None,
#    2075 ) -> DataFrame | Iterator[DataFrame]:
#    2077     args = _convert_params(sql, params)
# -> 2078     cursor = self.execute(*args)
#    2079     columns = [col_desc[0] for col_desc in cursor.description]
#    2081     if chunksize is not None:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2030, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2027     raise ex from inner_exc
#    2029 ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2030 raise ex from exc
#
# DatabaseError: Execution failed on sql 'ALTER TABLE products ADD COLUMN profit int': column "profit" of relation "products" already exists

# %%
profit_values = [pd.read_sql_query("UPDATE products SET profit = (selling_price - buying_price) * sales.quantity FROM sales",conn)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 profit_values = [pd.read_sql_query("UPDATE products SET profit = (selling_price - buying_price) * sales.quantity FROM sales",conn)]
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:397, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     339 """
#     340 Read SQL query into a DataFrame.
#     341
#    (...)
#     394 parameter will be converted to UTC.
#     395 """
#     396 pandas_sql = pandasSQL_builder(con)
# --> 397 return pandas_sql.read_query(
#     398     sql,
#     399     index_col=index_col,
#     400     params=params,
#     401     coerce_float=coerce_float,
#     402     parse_dates=parse_dates,
#     403     chunksize=chunksize,
#     404     dtype=dtype,
#     405 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2079, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2077 args = _convert_params(sql, params)
#    2078 cursor = self.execute(*args)
# -> 2079 columns = [col_desc[0] for col_desc in cursor.description]
#    2081 if chunksize is not None:
#    2082     return self._query_iterator(
#    2083         cursor,
#    2084         chunksize,
#    (...)
#    2089         dtype=dtype,
#    2090     )
#
# TypeError: 'NoneType' object is not iterable

# %%
df
# Out:
#                                 product_name  buying_price  selling_price  \
# sales_id
# 1                         Vinegar - Tarragon            65             21
# 2                             Cloves - Whole            33             75
# 3              Pail - 15l White, With Handle            47             10
# 4         Chocolate - Pistoles, Lactee, Milk            75             37
# 5                                     Cassis            16             82
# 6                                 Sage Derby            11             18
# 7               Nantucket - Pomegranate Pear            53             25
# 8               Carbonated Water - Raspberry            84             11
# 9                             Milkettes - 2%            25             32
# 10                              Apple - Fuji            32             69
# 11             Soup - Campbells, Spinach Crm            51             45
# 12                Water - Spring Water 500ml            54             23
# 13                   Crab - Dungeness, Whole            90             31
# 14                                   Dasheen            14             32
# 15                       Vinegar - Champagne            71             64
# 16                        Cookies Cereal Nut            59             66
# 17                   Yogurt - Banana, 175 Gr            87             76
# 18                   Apples - Sliced / Wedge            95             85
# 19           Pastry - Key Limepoppy Seed Tea            36             69
# 20                         Crab - Soft Shell             6             42
# 21                     Creme De Menthe Green            42            100
# 22             Pastry - Apple Muffins - Mini            14             57
# 23                       Fiddlehead - Frozen            73             34
# 24                             Leeks - Large            34             37
# 25                    Wine - Ruffino Chianti            55             17
# 26             Temperature Recording Station            47             16
# 27                        Bread - Rolls, Rye             6             72
# 28                  Chicken Thigh - Bone Out            14             57
# 29                          Soup - Campbells            24             46
# 30                        Beef - Rib Eye Aaa            49             97
# 31                              Veal - Heart            78             99
# 32                        Calypso - Lemonade            35             60
# 33                 Bagel - 12 Grain Preslice            14             23
# 34                         Wiberg Super Cure            20             67
# 35                        Beef - Flank Steak            44              9
# 36                      Beef - Prime Rib Aaa            69             62
# 37                    Butter - Salted, Micro            26             74
# 38                     Mushroom - Portebello             5             76
# 39                   Chips - Potato Jalapeno            88              3
# 40                      Dc Hikiage Hira Huba            49             93
# 41          Wine - White, Schroder And Schyl            34             47
# 42                                  Contreau            28             80
# 43                          Bread Ww Cluster            44             62
# 44                 Nantucket - Carrot Orange            32             75
# 45                      Pastry - Apple Large            28             84
# 46           Wine - Ruffino Chianti Classico           100             76
# 47                          Bag - Clear 7 Lb            10              6
# 48              Wine La Vielle Ferme Cote Du            36             94
# 49                        Bread - Pita, Mini            43             92
# 50                Nori Sea Weed - Gold Label            90             33
#
#           sales_quantity sales_created_at
# sales_id
# 1                     23       2022-11-13
# 2                     12       2022-08-31
# 3                     92       2022-12-29
# 4                     17       2023-04-08
# 5                    100       2023-05-25
# 6                     85       2023-04-16
# 7                     58       2022-08-25
# 8                     87       2023-03-05
# 9                     35       2023-01-12
# 10                    66       2023-04-26
# 11                    54       2023-04-24
# 12                    84       2023-05-08
# 13                    51       2022-08-30
# 14                     3       2023-02-17
# 15                    41       2023-01-31
# 16                    69       2023-07-27
# 17                    80       2023-07-02
# 18                    36       2023-03-11
# 19                    87       2023-07-26
# 20                    19       2023-07-05
# 21                    76       2022-12-30
# 22                    59       2022-11-04
# 23                    88       2023-02-04
# 24                    81       2023-06-13
# 25                    46       2023-07-03
# 26                    70       2023-06-18
# 27                    87       2023-07-21
# 28                    11       2023-02-10
# 29                    77       2022-08-16
# 30                    24       2022-10-05
# 31                    42       2023-07-08
# 32                    45       2023-07-27
# 33                    18       2023-03-26
# 34                   100       2023-06-22
# 35                     4       2023-04-12
# 36                    99       2023-06-26
# 37                    57       2023-03-14
# 38                    75       2023-01-17
# 39                    47       2022-09-20
# 40                    74       2023-04-24
# 41                    70       2022-12-09
# 42                    28       2022-11-12
# 43                    98       2023-03-05
# 44                    13       2023-01-08
# 45                    85       2022-12-24
# 46                    88       2022-09-12
# 47                    58       2022-11-27
# 48                    90       2023-03-31
# 49                    54       2023-05-13
# 50                    69       2023-06-05
