# %%
! pip install PyMySQL
! pip install ipython-sql
! pip install mysqlclient

# %%
# !pip install pymysql
# !pip install psycopg2

# %% [markdown]
# ### 1.Importing modules that interact with the database.

# %%
import sqlalchemy
import pandas as pd
import psycopg2

# %% [markdown]
# ### 2.Create an engine that connects to the database.

# %%
engine = sqlalchemy.create_engine("postgresql://postgres:Candidcoco@20@localhost:5432/postgres")

# %% [markdown]
# ### 3. Load sql extension.

# %%
# %load_ext sql

# %% [markdown]
# ### 4. Establish the connection.

# %%
# %sql $engine.url
# Out:
# 'Connected: postgres@postgres'

# %% [markdown]
# ### 4. Querying tables from the database.

# %%
# %sql SELECT id, name, buying_price, selling_price, quantity from products
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 45 rows affected.
# [(1, 'sweet', Decimal('70.00'), Decimal('80.00'), 300),
#  (3, 'pineapple', Decimal('70.00'), Decimal('200.00'), 5),
#  (4, 'biscuit', Decimal('60.00'), Decimal('80.00'), 7),
#  (5, 'popcorn', Decimal('50.00'), Decimal('50.00'), 30),
#  (2, 'cake', Decimal('10.00'), Decimal('20.00'), 100),
#  (6, 'Lettuce', Decimal('40.00'), Decimal('50.00'), 50),
#  (8, 'waffles', Decimal('25.00'), Decimal('40.00'), 10),
#  (7, 'broccoli', Decimal('40.00'), Decimal('60.00'), 100),
#  (9, 'Wheat', Decimal('40.00'), Decimal('60.00'), 100),
#  (10, 'coffee', Decimal('50.00'), Decimal('60.00'), 70),
#  (11, 'juice', Decimal('50.00'), Decimal('60.00'), 600),
#  (12, 'pencil', Decimal('5.00'), Decimal('10.00'), 200),
#  (13, 'bread', Decimal('50.00'), Decimal('55.00'), 50),
#  (14, 'milk', Decimal('45.00'), Decimal('50.00'), 70),
#  (15, 'coconut', Decimal('60.00'), Decimal('65.00'), 80),
# ...

# %%
df = pd.DataFrame(columns=['sales_id','product_name','buying_price','selling_price','quantity','created_at'])

df.set_index('sales_id',inplace=False,verify_integrity=False)
# Out:
# Empty DataFrame
# Columns: [product_name, buying_price, selling_price, quantity, created_at]
# Index: []
